# %%
SELECT
ROUND(AVG(standard _ cost ), 2) avg_std_cost
FROM
products;

# %%
SELECT
ROUND(AVG(standard-cost),2) avg_std_cost.
ROUND(AVG(list_price ) . 2) avg_list_price
FROM
products;

# %%
SELECT
RCJND(
AVG( DISTINCT list_price ),
2
) avg_list_price
FROM
products ;

# %%
SELECT
category_id,
ROUND(
AVG( list_pnce ).
2
) avg_list_price
FROM
products
GROUP BY
category_id;

# %%
SELECT
category_name
ROUND( AVG(list_price),2 ) avg_list_price
FROM
products
INNER JOIN product_categories
USING(category_id)
GROUP BY
category_name
ORDER BY
category_name;

# %%
SELECT
category_name,
ROUND(
AVG( list-price),
2
) avg_list_price
FROM
products
INNER JOIN product_categories
USING(category-id)
GROUP BY
category_name
HAVING
AVG( list_price )> 1000
ORDER BY
category_name;

# %%
SELECT
ROUND( AVG( avg_list_price ) . 2) avg_of_avg
FROM
(
SELECT
AVG(list_price) avg_list_price
FROM
products
GROUP BY
category_id
);

# %%
CREATE TABLE tests (
employee_id NUMBER PRIYARY KEY.
score NUMBER(3,1)
);
INSERT INTO tests(employee_id, score) VALIES(1, 95);
INSERT INTO tests(employee_id, score) VALIES(2, 70);
INSERT INTO tests(employee_id, score) VALIES(3, 60);
INSERT INTO tests(employee_id, score) VALIES(4, null);

SELECT * FROM tests;

# %%
SELECT
AVG( score)
FROM
tests:

# %%
SELECT
AVG( NVL( score, 0 ) )
FROM
tests ;

# %%
CREATE TABLE items(val number);
INSERT INTO items(val) VALUES(1);
INSERT INTO items(val) VALUES(1);
INSERT INTO items(val) VALUES(2);
INSERT INTO items(val) VALUES(3);
INSERT INTO items(val) VALUES(NULL);
INSERT INTO items(val) VALUES(4);
INSERT INTO items(val) VALUES(NULL);

SELECT * FROM items;

# %%
SELECT
COUNT (*)
FROM
items;

# %%
SELECT
COUNT(DISTINCT val)
FROM
items;

# %%
SELECT
COUNT( ALL val )
FROM
items;

# %%
SELECT
COUNT(*)
FROM
products;

# %%
SELECT
COUNT (*)
FROM
products
WHERE
category_id = 1;

# %%
SELECT
category_id ,
COUNT(*)
FROM
products
GROUP BY
category_id
ORDER BY
category_id;

# %%
SELECT
category_name,
COUNT( product_id )
FROM
product_categories
LEFT JOIN products
USING ( category_id)
GROUP BY
category_name
ORDER BY
category_name ;

# %%
SELECT
category_name,
COUNT( product_id )
FROM
product_cateqories
 LEFT JOIN products
USING(category-id)
GROUP BY
category_name
HAVING
COUNT( product_id ) > 50
ORDER BY
category_name;

# %%
SELECT
last_name,
COUNT( last_name )
FROM
contacts
GROUP BY
last_nane
HAVING
COUNT( last_name)> 1
ORDER BY
last_name;

# %%
SELECT
MAX(list_price)
FROM
products:

# %%
SELECT
product_id,
product_name,
list_price
FROM
products
WHERE
list_price =(
SELECT
MAX( list_price )
FROM
products
);

# %%
SELECT
category_ld,
MAX(list_price )
FROM
products
GROUP BY
category_id
ORDER BY
category_id;

# %%
SELECT
category_name,
MAX( list_price )
FROM
products
INNER JOIN product_categories
USING ( category_id)
GROUP BY
category_name
ORDER BY
category_name ;

# %%
SELECT
category_name,
MAX( list_price )
FROM
products
INNER JOIN product_categories
USING(category_id)
GROUP BY
category_name
HAVING
MAX(list_price ) BETWEEN 3000 AND 6000
ORDER BY
category_name;

# %%
SELECT
MIN( list_price )
FROM
products;

# %%
SELECT
product_id,
product_name ,
list_price
FROM
products
WHERE
list_price =(
SELECT
MIN( list_price )
FROM
products
);

# %%
SELECT
category_id.
MIN( list_price )
FROM
products
GROUP BY
category_ld
ORDER BY
category_ld;

# %%
SELECT
category_name,
MIN( list_price )
FROM
products
INNER JOIN product_categories
USING(category_id)
GROUP BY
category_name
ORDER BY
category_name;

# %%
SELECT
category_name,
MIN( list_price )
FROM
products
INNER JOIN product_categories
USING(category_id)
GROUP BY
category_name
HAVING
MIN( list_price )>500
ORDER BY
category_name ;

# %%
SELECT
SUM( quantity )
FROM
order_itens;

# %%
SELECT
product_id ,
SUM( quantity )
FROM
order_items
GROUP BY
product_id
ORDER BY
SUM( quantity ) DESC;

# %%
SELECT
order-id,
SUM( quantity * unit_price ) order_total
FROM
order_items
GROUP BY
order_id
ORDER BY
order_total;

# %%
SELECT
order-id,
SUM( quantity * unit_price ) order_total
FROM
order_items
GROUP BY
order_id
HAVING
SUM( quantity * unit_price ) BETWEEN 1000 AND 20000
ORDER BY
order_total DESC;

# %%
SELECT
product_name,
SUM( quantity * untt_price ) sales
FROM
order_items
INNER JOIN products
USING(product_id)
GROUP BY
product_name
ORDER BY
sales DESC;
