# %%
SELECT
CHR( 83 ) ,
CHR( 115 )
FROM
dual;

# %%
SELECT
CHR( NULL )
FROM
DUAL;

# %%
SELECT
first_nane || ' ' || last_name ||
CHR (9) || ' joined on ' || CHR(9) ||
to_char(hire_date,'DO-MON-YYYY') first_5_employess
FROM
employees
ORDER BY
hire_date
FETCH
FIRST 5 ROWS ONLY;

# %%
SELECT
CONCAT( 'Happy' , 'coding' )
FROM
dual ;

# %%
SELECT
CONCAT( CONCAT('Happy', 'coding'), 'together')
FROM
dual;

# %%
SELECT
'Happy' || 'coding' || 'together'
FROM
dual;

# %%
SELECT
first_name || ' ' || last_name
FROM
employees;

# %%
SELECT
CONCAT('let' 's', 'try this' )
FROY
dual;

# %%
SELECT
INSTR('This iS a playlist ', 'is' ) substring_location
FROM
dual;

# %%
SELECT
INSTR ('This is a playlist', 'is', 1,2) second_occurrence,
INSTR('This is a playlist', 'is', 1,3) third_occurrence
FROM
dual;

# %%
SELECT
INSTR('This is a playlist', 'are') substring_location
FROM
dual;

# %%
SELECT
INSTR ('This is a playlist ' , 'is', -1 ) substring_location
FROM
dual;

# %%
SELECT
INITCAP( 'hi john' )
FROM
DUAL;

# %%
SELECT
INITCAP( tirst_name ||' ' || last_name) full_name
FROM
contacts
ORDER BY
full_name;

# %%
SELECT
'oracle LENGTH ' string,
LENGTH( 'oracle LENGTH') Len
FROM
dual :

# %%
SELECT
first_name,
LENGTH(first_name)
FROM
employees
ORDER BY
LENGTH(first_name) DESC;

# %%
SELECT
LENGTH( first_name ) len,
COUNT(*)
FROM
employees
GROUP BY
LENGTH( first_name )
ORDER BY Len;

# %%
SELECT
product_name,
CASE
WHEN LENGTH( description )> 50 THEN CONCAT( SUBSTR( description, 1,50), '...)'
ELSE description
END product_excerpt
FROM
products
ORDER BY
product_name ;

# %%
SELECT
LTRIP('XYZ')
FROM
dual;

# %%
SELECT
LTRIM('123456XYZ', '123')
FROM
dual;

# %%
SELECT
products_name
FROM
products
WHERE
product_name LIKE 'ASRock%'
ORDER BY
product_name;

# %%
SELECT
product_name,
LTRIM( product_name, 'ASRock') short_product_name
FROM
products
WHERE
product_name LIKE 'ASRock%'
ORDER BY
product_name;

# %%
SELECT
REPLACE ('This is a test', 'is', 'IS')
FROM
dual;

# %%
CREATE TABLE articles(
article_id NUMBER GENERATED BY DEFAULT AS IDENTITY,
title VARCHAR2( 255 ) ,
article_body VARCHAR2(4000) ,
PRIMARY KEY (article_id)
);

# %%
SELECT
article_ld, title, article_body
FROM
articles;

# %%
UPDATE
articles
SET
article-body= REPLACE(article-body, '<strong', '<b>');
UPDATE
articles
SET
article_body = REPLACE(article_body, '</stronge>', '</b>');

# %%
SELECT
article_id, title, article_body
FROM
articles;
